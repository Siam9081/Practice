# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\User\Desktop\Sam\Data_Set\employee.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years department  \
# 0                   3              0                      0      sales
# 1                   6              0                      0      sales
# 2                   4              0                      0      sales
# 3                   5              0                      0      sales
# 4                   3              0                      0      sales
#
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['department'] = le.fit_transform(df['department'])

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years  department  \
# 0                   3              0                      0           7
# 1                   6              0                      0           7
# 2                   4              0                      0           7
# 3                   5              0                      0           7
# 4                   3              0                      0           7
#
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# ...

# %%
df['salary'] = le.fit_transform(df['salary'])

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years  department  \
# 0                   3              0                      0           7
# 1                   6              0                      0           7
# 2                   4              0                      0           7
# 3                   5              0                      0           7
# 4                   3              0                      0           7
#
#    salary  left
# 0       1     1
# 1       2     1
# 2       2     1
# ...

# %%
X = df.drop(columns=['left'], axis= 1)
y = df['left']

# %%
df['left'].value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X , y, test_size= 0.30, random_state= 42)

# %%
dclf = DecisionTreeClassifier()

# %%
dclf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dclf.score(X_test, y_test)
# Out:
# 0.9746666666666667

# %%
rclf = RandomForestClassifier()

# %%
rclf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rclf.score(X_test, y_test)
# Out:
# 0.9875555555555555

# %%
rclf.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
rclf.predict([[0.38,0.53,2,157,3,0,0,7,1]])
# Out:
# array([1], dtype=int64)

# %%
rclf.predict([[0.80,0.86,5,562,6,0,0,7,2]])
# Out:
# array([1], dtype=int64)

# %%
rclf.predict([[0.38,0.53,2,157,3,0,0,7,1]])
# Out:
# array([1], dtype=int64)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                   3              0
# 1                       262                   6              0
# 2                       272                   4              0
# ...

# %%
df['department'].value_counts()
# Out:
# department
# 7    4140
# 9    2720
# 8    2229
# 0    1227
# 6     902
# 5     858
# 1     787
# 2     767
# 3     739
# 4     630
# Name: count, dtype: int64

# %%
rclf.predict([[0.38,0.53,2,157,3,0,0,4,1]])
# Out:
# array([1], dtype=int64)

# %%
rclf.predict([[0.38,0.53,2,157,3,0,0,7,1]])
# Out:
# array([1], dtype=int64)

# %%
rclf.predict([[0.38,0.53,2,157,3,0,0,7,1]])
# Out:
# array([1], dtype=int64)

# %%
rclf.predict([[0.38,0.53,2,157,3,0,0,7,1]])
rclf.predict([[0.38,0.53,2,157,3,0,0,7,1]])
# Out:
# array([1], dtype=int64)

# %%
rclf.predict([[0.38,0.53,2,157,3,0,0,6,1]])
# Out:
# array([1], dtype=int64)

# %%
rclf.predict([[0.38,0.53,2,157,3,0,0,7,1]])
# Out:
# array([1], dtype=int64)

# %%
import warnings as wr
wr.filterwarnings('ignore')

# %%
import pickle as pk

# %%
with open('sa.pkl','wb') as file:
    pk.dump(rclf,file)

# %%
from joblib import dump, load

# %%
dump(rclf, 'saving')
# Out:
# ['saving']
